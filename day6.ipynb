# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
model = Sequential()
model.add(Input(shape=(28,28,1))) # 28x28크기 채널이 1개인 이미지(grayscale)

# 첫 번째 합성곱층
model.add(Conv2D(32, 5, activation='relu', padding='same'))
model.add(MaxPooling2D())
model.add(Dropout(0.1))

# 두 번째 합성곱층
model.add(Conv2D(64, 3, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.25))

# 2차원 이미지들을 1차원으로 만듬
model.add(Flatten())

# 은닉층
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))

# 출력층
model.add(Dense(10, activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        832
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  dropout_3 (Dropout)         (None, 14, 14, 32)        0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 64)        18496
#
#  max_pooling2d_3 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_2 (Dense)             (None, 128)               295040
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 315658 (1.20 MB)
# Trainable params: 315658 (1.20 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.datasets import mnist
(train_X, train_y), (test_X, test_y) = mnist.load_data()
train_X.shape, train_y.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 1s 0us/step
# ((60000, 28, 28), (60000,))

# %%
train_X = train_X.reshape(-1, 28, 28, 1) / 255.0
test_X = test_X.reshape(-1, 28, 28, 1) / 255.0

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer='adam', metrics=["accuracy"])

# %%
model.fit(train_X, train_y, validation_data=(test_X, test_y),
          batch_size=128, epochs=10, verbose=1)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 8s 6ms/step - loss: 0.3128 - accuracy: 0.9025 - val_loss: 0.0556 - val_accuracy: 0.9821
# Epoch 2/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0993 - accuracy: 0.9704 - val_loss: 0.0360 - val_accuracy: 0.9880
# Epoch 3/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0736 - accuracy: 0.9784 - val_loss: 0.0322 - val_accuracy: 0.9901
# Epoch 4/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0610 - accuracy: 0.9819 - val_loss: 0.0268 - val_accuracy: 0.9913
# Epoch 5/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0521 - accuracy: 0.9836 - val_loss: 0.0270 - val_accuracy: 0.9902
# Epoch 6/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0486 - accuracy: 0.9855 - val_loss: 0.0232 - val_accuracy: 0.9930
# Epoch 7/10
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0442 - accuracy: 0.9866 - val_loss: 0.0247 - val_accuracy: 0.9912
# Epoch 8/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0382 - accuracy: 0.9886 - val_loss: 0.0223 - val_accuracy: 0.9934
# Epoch 9/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0358 - accuracy: 0.9891 - val_loss: 0.0209 - val_accuracy: 0.9933
# Epoch 10/10
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0337 - accuracy: 0.9896 - val_loss: 0.0228 - val_accuracy: 0.9920

# %%
model.evaluate(test_X, test_y)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0228 - accuracy: 0.9920
# [0.022835327312350273, 0.9919999837875366]
